# %% [markdown]
# <a href="https://colab.research.google.com/github/MaCuur/AI_EGs/blob/main/lstm_ext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LSTM for begginers

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import MonthLocator, DateFormatter, YearLocator
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.layers import Dense, InputLayer, LSTM
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Loading data

# %%
train = pd.read_csv('data/DailyDelhiClimateTrain.csv')
test = pd.read_csv('data/DailyDelhiClimateTest.csv')

# %%
train.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
print(f"train_shape: {train.shape}")
print(f"test_shape: {test.shape}")
# Out:
# train_shape: (1462, 5)
# test_shape: (114, 5)

# %% [markdown]
# ## Preprocessing

# %%
WINDOW_SIZE = 5

# %%
def data_to_input_and_output(data):

    input_data = []
    output_data = []
    for index in range(0, len(data) - WINDOW_SIZE):
        input_sample = data['meantemp'][index:index + WINDOW_SIZE]
        output_sample = data['meantemp'][index + WINDOW_SIZE]

        input_data.append(input_sample)
        output_data.append(output_sample)

    return np.array(input_data), np.array(output_data)

# %%
train_input, train_output = data_to_input_and_output(train)
test_input, test_output = data_to_input_and_output(test)

# %% [markdown]
# ## Building and traing the neural network

# %%
#model = load_model('model/')
def train_neural_network(X, y, epochs=5, learning_rate=0.005):

    model = Sequential()
    model.add(InputLayer((WINDOW_SIZE, 1)))
    model.add(LSTM(64))
    model.add(Dense(8, 'relu'))
    model.add(Dense(1, 'linear'))

    check_point = ModelCheckpoint('model/model.keras', save_best_only=True, monitor='loss')
    model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=learning_rate), metrics=[RootMeanSquaredError()])
    model.fit(X, y, epochs=epochs, callbacks=[check_point])
    return model

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3029673797.py in <cell line: 0>()
# ----> 1 train_neural_network(train_input, train_output, epochs=100, learning_rate=0.005)
#
# /tmp/ipython-input-534496769.py in train_neural_network(X, y, epochs, learning_rate)
#       8     model.add(Dense(1, 'linear'))
#       9
# ---> 10     check_point = ModelCheckpoint('model/', save_best_only=True, monitor='loss')
#      11     model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=learning_rate), metrics=[RootMeanSquaredError()])
#      12     model.fit(X, y, epochs=epochs, callbacks=[check_point])
#
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/model_checkpoint.py in __init__(self, filepath, monitor, verbose, save_best_only, save_weights_only, mode, save_freq, initial_value_threshold)
#     192                 self.filepath.endswith(ext) for ext in (".keras", ".h5")
#     193             ):
# --> 194                 raise ValueError(
#     195                     "The filepath provided must end in `.keras` "
#     196                     "(Keras model format). Received: "
#
# ValueError: The filepath provided must end in `.keras` (Keras model format). Received: filepath=model/

# %% [markdown]
# ## Predictions

# %%
model = load_model('model/')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-522094327.py in <cell line: 0>()
# ----> 1 model = load_model('model/')
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     204         )
#     205     else:
# --> 206         raise ValueError(
#     207             f"File format not supported: filepath={filepath}. "
#     208             "Keras 3 only supports V3 `.keras` files and "
#
# ValueError: File format not supported: filepath=model/. Keras 3 only supports V3 `.keras` files and legacy H5 format files (`.h5` extension). Note that the legacy SavedModel format is not supported by `load_model()` in Keras 3. In order to reload a TensorFlow SavedModel as an inference-only layer in Keras 3, use `keras.layers.TFSMLayer(model/, call_endpoint='serving_default')` (note that your `call_endpoint` might have a different name).

# %%
train_pred = model.predict(train_input)
test_pred = model.predict(test_input)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3500521440.py in <cell line: 0>()
# ----> 1 train_pred = model.predict(train_input)
#       2 test_pred = model.predict(test_input)
#
# NameError: name 'model' is not defined

# %%
def plot_predictions(pred, y_true, label, period):
    # Convert period to datetime if it's not already
    period = pd.to_datetime(period)

    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(period, y_true, label='True Values', marker='o', color='black')
    plt.plot(period, pred, label='Predictions', marker='o', color='red')

    # Adding labels and title
    plt.xlabel('Date')
    plt.ylabel('Mean temperature')
    plt.title(label)

    # Adding legend
    plt.legend()

    if label == "Train Data":
        # Format X-axis to show only years
        plt.gca().xaxis.set_major_locator(YearLocator())
        plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))
    elif label == "Test Data":
        # Format X-axis to show only months
        plt.gca().xaxis.set_major_locator(MonthLocator())
        plt.gca().xaxis.set_major_formatter(DateFormatter('%b %Y'))

    # Rotate x-axis labels for better visibility
    plt.gcf().autofmt_xdate()

    # Show the plot
    plt.show()

# %%
train_period = train[0:len(train) - WINDOW_SIZE]['date']
test_period = test[0:len(test) - WINDOW_SIZE]['date']

plot_predictions(train_pred, train_output, 'Train Data', train_period)
plot_predictions(test_pred, test_output, 'Test Data', test_period)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1892613625.py in <cell line: 0>()
#       2 test_period = test[0:len(test) - WINDOW_SIZE]['date']
#       3
# ----> 4 plot_predictions(train_pred, train_output, 'Train Data', train_period)
#       5 plot_predictions(test_pred, test_output, 'Test Data', test_period)
#
# NameError: name 'train_pred' is not defined

# %% [markdown]
# ## How to predict the future?

# %%
predictions = []

def predict_the_future(input_seq, period_prediction: int = 7):
    if period_prediction == 0:
        return None
    new_prediction = model.predict(input_seq)
    predictions.append(new_prediction[0][0])

    # input_seq = [[0], [1], [2], [3], [4]]
    # prediction = [5]
    # --> new_seq = [[1], [2], [3], [4], [5]]
    new_seq = np.array([np.concatenate((input_seq[0][1:WINDOW_SIZE], new_prediction[0]))])

    predict_the_future(new_seq, period_prediction - 1)

# %%
seq_start = np.array([[15, 15.5, 16, 17, 18]])

if len(seq_start[0]) != WINDOW_SIZE:
    raise "Size mismatch"
predict_the_future(seq_start)

predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1888537292.py in <cell line: 0>()
#       3 if len(seq_start[0]) != WINDOW_SIZE:
#       4     raise "Size mismatch"
# ----> 5 predict_the_future(seq_start)
#       6
#       7 predictions
#
# /tmp/ipython-input-3484793602.py in predict_the_future(input_seq, period_prediction)
#       4     if period_prediction == 0:
#       5         return None
# ----> 6     new_prediction = model.predict(input_seq)
#       7     predictions.append(new_prediction[0][0])
#       8
#
# NameError: name 'model' is not defined

# %%
model = load_model('model/model.keras')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-241429988.py in <cell line: 0>()
# ----> 1 model = load_model('model/model.keras')
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     198         )
#     199     elif str(filepath).endswith(".keras"):
# --> 200         raise ValueError(
#     201             f"File not found: filepath={filepath}. "
#     202             "Please ensure the file is an accessible `.keras` "
#
# ValueError: File not found: filepath=model/model.keras. Please ensure the file is an accessible `.keras` zip file.

# %%
train_pred = model.predict(train_input)
test_pred = model.predict(test_input)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3500521440.py in <cell line: 0>()
# ----> 1 train_pred = model.predict(train_input)
#       2 test_pred = model.predict(test_input)
#
# NameError: name 'model' is not defined

# %%
train_period = train[0:len(train) - WINDOW_SIZE]['date']
test_period = test[0:len(test) - WINDOW_SIZE]['date']

plot_predictions(train_pred, train_output, 'Train Data', train_period)
plot_predictions(test_pred, test_output, 'Test Data', test_period)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1892613625.py in <cell line: 0>()
#       2 test_period = test[0:len(test) - WINDOW_SIZE]['date']
#       3
# ----> 4 plot_predictions(train_pred, train_output, 'Train Data', train_period)
#       5 plot_predictions(test_pred, test_output, 'Test Data', test_period)
#
# NameError: name 'plot_predictions' is not defined

# %%
WINDOW_SIZE = 5

# %%
def data_to_input_and_output(data):

    input_data = []
    output_data = []
    for index in range(0, len(data) - WINDOW_SIZE):
        input_sample = data['meantemp'][index:index + WINDOW_SIZE]
        output_sample = data['meantemp'][index + WINDOW_SIZE]

        input_data.append(input_sample)
        output_data.append(output_sample)

    return np.array(input_data), np.array(output_data)

# %%
train_input, train_output = data_to_input_and_output(train)
test_input, test_output = data_to_input_and_output(test)

# %%
def plot_predictions(pred, y_true, label, period):
    # Convert period to datetime if it's not already
    period = pd.to_datetime(period)

    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(period, y_true, label='True Values', marker='o', color='black')
    plt.plot(period, pred, label='Predictions', marker='o', color='red')

    # Adding labels and title
    plt.xlabel('Date')
    plt.ylabel('Mean temperature')
    plt.title(label)

    # Adding legend
    plt.legend()

    if label == "Train Data":
        # Format X-axis to show only years
        plt.gca().xaxis.set_major_locator(YearLocator())
        plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))
    elif label == "Test Data":
        # Format X-axis to show only months
        plt.gca().xaxis.set_major_locator(MonthLocator())
        plt.gca().xaxis.set_major_formatter(DateFormatter('%b %Y'))

    # Rotate x-axis labels for better visibility
    plt.gcf().autofmt_xdate()

    # Show the plot
    plt.show()

# %%
model = load_model('model/model.keras')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-241429988.py in <cell line: 0>()
# ----> 1 model = load_model('model/model.keras')
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     198         )
#     199     elif str(filepath).endswith(".keras"):
# --> 200         raise ValueError(
#     201             f"File not found: filepath={filepath}. "
#     202             "Please ensure the file is an accessible `.keras` "
#
# ValueError: File not found: filepath=model/model.keras. Please ensure the file is an accessible `.keras` zip file.

# %%
train_pred = model.predict(train_input)
test_pred = model.predict(test_input)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3500521440.py in <cell line: 0>()
# ----> 1 train_pred = model.predict(train_input)
#       2 test_pred = model.predict(test_input)
#
# NameError: name 'model' is not defined

# %%
train_period = train[0:len(train) - WINDOW_SIZE]['date']
test_period = test[0:len(test) - WINDOW_SIZE]['date']

plot_predictions(train_pred, train_output, 'Train Data', train_period)
plot_predictions(test_pred, test_output, 'Test Data', test_period)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1892613625.py in <cell line: 0>()
#       2 test_period = test[0:len(test) - WINDOW_SIZE]['date']
#       3
# ----> 4 plot_predictions(train_pred, train_output, 'Train Data', train_period)
#       5 plot_predictions(test_pred, test_output, 'Test Data', test_period)
#
# NameError: name 'train_pred' is not defined

# %%
train_neural_network(train_input, train_output, epochs=100, learning_rate=0.005)
# Out:
# Epoch 1/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 603.8600 - root_mean_squared_error: 24.5506
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 191.6621 - root_mean_squared_error: 13.7211
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 44.2970 - root_mean_squared_error: 6.6250
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2871 - root_mean_squared_error: 2.4961
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6225 - root_mean_squared_error: 1.9011
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4959 - root_mean_squared_error: 1.8672
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8810 - root_mean_squared_error: 1.6969
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0885 - root_mean_squared_error: 1.7564
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.0670 - root_mean_squared_error: 1.7506
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.9057 - root_mean_squared_error: 1.7040
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8863 - root_mean_squared_error: 1.6968
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.9380 - root_mean_squared_error: 1.7138
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.7767 - root_mean_squared_error: 1.6651
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8858 - root_mean_squared_error: 1.6985
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6901 - root_mean_squared_error: 1.6383
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1600 - root_mean_squared_error: 1.7771
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6716 - root_mean_squared_error: 1.6338
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0594 - root_mean_squared_error: 1.7482
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0186 - root_mean_squared_error: 1.7370
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6929 - root_mean_squared_error: 1.6406
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6919 - root_mean_squared_error: 1.6382
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5803 - root_mean_squared_error: 1.6045
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9520 - root_mean_squared_error: 1.7170
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.5761 - root_mean_squared_error: 1.6047
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8327 - root_mean_squared_error: 1.6823
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8698 - root_mean_squared_error: 1.6927
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1927 - root_mean_squared_error: 1.7816
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8737 - root_mean_squared_error: 1.6942
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2848 - root_mean_squared_error: 1.8118
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3235 - root_mean_squared_error: 1.8209
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7530 - root_mean_squared_error: 1.6582
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6228 - root_mean_squared_error: 1.6187
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8327 - root_mean_squared_error: 1.6823
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8753 - root_mean_squared_error: 1.6951
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5758 - root_mean_squared_error: 1.6032
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7915 - root_mean_squared_error: 1.6702
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9726 - root_mean_squared_error: 1.7234
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6934 - root_mean_squared_error: 1.6402
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8558 - root_mean_squared_error: 1.6895
# Epoch 40/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8163 - root_mean_squared_error: 1.6744
# Epoch 41/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9038 - root_mean_squared_error: 1.7037
# Epoch 42/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7653 - root_mean_squared_error: 1.6623
# Epoch 43/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7527 - root_mean_squared_error: 1.6588
# Epoch 44/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.6268 - root_mean_squared_error: 1.6200
# Epoch 45/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9944 - root_mean_squared_error: 1.7290
# Epoch 46/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7430 - root_mean_squared_error: 1.6545
# Epoch 47/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8897 - root_mean_squared_error: 1.6963
# Epoch 48/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9486 - root_mean_squared_error: 1.7090
# Epoch 49/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7151 - root_mean_squared_error: 1.6474
# Epoch 50/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.6846 - root_mean_squared_error: 1.6367
# Epoch 51/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.5542 - root_mean_squared_error: 1.5975
# Epoch 52/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0138 - root_mean_squared_error: 1.7350
# Epoch 53/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6477 - root_mean_squared_error: 1.6261
# Epoch 54/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8714 - root_mean_squared_error: 1.6941
# Epoch 55/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7594 - root_mean_squared_error: 1.6604
# Epoch 56/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5024 - root_mean_squared_error: 1.5800
# Epoch 57/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4930 - root_mean_squared_error: 1.5765
# Epoch 58/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2383 - root_mean_squared_error: 1.7986
# Epoch 59/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6742 - root_mean_squared_error: 1.6335
# Epoch 60/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0594 - root_mean_squared_error: 1.7462
# Epoch 61/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7808 - root_mean_squared_error: 1.6667
# Epoch 62/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5380 - root_mean_squared_error: 1.5929
# Epoch 63/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0538 - root_mean_squared_error: 1.7417
# Epoch 64/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4613 - root_mean_squared_error: 1.5671
# Epoch 65/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5022 - root_mean_squared_error: 1.5806
# Epoch 66/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.6902 - root_mean_squared_error: 1.6391
# Epoch 67/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7019 - root_mean_squared_error: 1.6427
# Epoch 68/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6772 - root_mean_squared_error: 1.6359
# Epoch 69/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9064 - root_mean_squared_error: 1.7029
# Epoch 70/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5052 - root_mean_squared_error: 1.5807
# Epoch 71/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6386 - root_mean_squared_error: 1.6240
# Epoch 72/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5481 - root_mean_squared_error: 1.5960
# Epoch 73/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0232 - root_mean_squared_error: 1.7384
# Epoch 74/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9321 - root_mean_squared_error: 1.7099
# Epoch 75/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6893 - root_mean_squared_error: 1.6396
# Epoch 76/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3485 - root_mean_squared_error: 1.5304
# Epoch 77/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8275 - root_mean_squared_error: 1.6793
# Epoch 78/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4603 - root_mean_squared_error: 1.5681
# Epoch 79/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5156 - root_mean_squared_error: 1.5853
# Epoch 80/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5182 - root_mean_squared_error: 1.5865
# Epoch 81/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7361 - root_mean_squared_error: 1.6527
# Epoch 82/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0653 - root_mean_squared_error: 1.7484
# Epoch 83/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5326 - root_mean_squared_error: 1.5908
# Epoch 84/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5291 - root_mean_squared_error: 1.5896
# Epoch 85/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.7099 - root_mean_squared_error: 1.6450
# Epoch 86/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.8306 - root_mean_squared_error: 1.6804
# Epoch 87/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.7038 - root_mean_squared_error: 1.6434
# Epoch 88/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.5585 - root_mean_squared_error: 1.5973
# Epoch 89/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6013 - root_mean_squared_error: 1.6116
# Epoch 90/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8084 - root_mean_squared_error: 1.6755
# Epoch 91/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6197 - root_mean_squared_error: 1.6177
# Epoch 92/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7751 - root_mean_squared_error: 1.6618
# Epoch 93/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6528 - root_mean_squared_error: 1.6273
# Epoch 94/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6961 - root_mean_squared_error: 1.6404
# Epoch 95/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5352 - root_mean_squared_error: 1.5918
# Epoch 96/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7778 - root_mean_squared_error: 1.6661
# Epoch 97/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6142 - root_mean_squared_error: 1.6163
# Epoch 98/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5977 - root_mean_squared_error: 1.6109
# Epoch 99/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0911 - root_mean_squared_error: 1.7560
# Epoch 100/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0461 - root_mean_squared_error: 1.7423
# <Sequential name=sequential_5, built=True>

# %%
model = load_model('model/model.keras')

# %%
train_pred = model.predict(train_input)
test_pred = model.predict(test_input)
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
train_period = train[0:len(train) - WINDOW_SIZE]['date']
test_period = test[0:len(test) - WINDOW_SIZE]['date']

plot_predictions(train_pred, train_output, 'Train Data', train_period)
plot_predictions(test_pred, test_output, 'Test Data', test_period)

# %%
predictions = []

def predict_the_future(input_seq, period_prediction: int = 3):
    if period_prediction == 0:
        return None
    new_prediction = model.predict(input_seq)
    predictions.append(new_prediction[0][0])

    # input_seq = [[0], [1], [2], [3], [4]]
    # prediction = [5]
    # --> new_seq = [[1], [2], [3], [4], [5]]
    new_seq = np.array([np.concatenate((input_seq[0][1:WINDOW_SIZE], new_prediction[0]))])

    predict_the_future(new_seq, period_prediction - 1)

# %%
seq_start = np.array([[20, 21, 22, 23, 24]]) # Changed starting sequence

if len(seq_start[0]) != WINDOW_SIZE:
    raise "Size mismatch"
predict_the_future(seq_start, period_prediction=30)

predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# [np.float32(23.401468),
#  np.float32(23.036097),
#  np.float32(22.852558),
#  np.float32(22.743479),
#  np.float32(22.61957),
#  np.float32(22.451178),
#  np.float32(22.268045),
#  np.float32(22.080843),
#  np.float32(21.889866),
#  np.float32(21.6924),
#  np.float32(21.487396),
#  np.float32(21.275717),
#  np.float32(21.058544),
#  np.float32(20.836933),
#  np.float32(20.611866),
#  np.float32(20.384409),
#  np.float32(20.155722),
#  np.float32(19.926994),
#  np.float32(19.699389),
#  np.float32(19.473997),
#  np.float32(19.251791),
#  np.float32(19.033627),
#  np.float32(18.820187),
#  np.float32(18.612015),
#  np.float32(18.40949),
#  np.float32(18.212831),
#  np.float32(18.022118),
#  np.float32(17.837276),
#  np.float32(17.658125),
#  np.float32(17.484377)]

# %%
# Assuming each prediction corresponds to a day after the input sequence
future_dates = pd.date_range(start='2017-04-25', periods=len(predictions), freq='D')

plt.figure(figsize=(10, 6))
plt.plot(future_dates, predictions, label='Future Predictions', marker='o', color='blue')

plt.xlabel('Date')
plt.ylabel('Mean temperature')
plt.title('Future Temperature Predictions')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %%
from sklearn.metrics import mean_squared_error

rmse = np.sqrt(mean_squared_error(test_output, test_pred))
print(f"Root Mean Squared Error (RMSE) on the test set: {rmse:.2f}")
# Out:
# Root Mean Squared Error (RMSE) on the test set: 1.73

# %%
# Assuming each prediction corresponds to a day after the input sequence
future_dates = pd.date_range(start='2017-04-25', periods=len(predictions), freq='D')

plt.figure(figsize=(10, 6))
plt.plot(future_dates, predictions, label='Future Predictions', marker='o', color='blue')

plt.xlabel('Date')
plt.ylabel('Mean temperature')
plt.title('Future Temperature Predictions (Different Starting Sequence)')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()
